# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../Datasets/Crop_recommendation.csv")

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
print("\nStatistiques descriptives:")
print(df.describe())
# Out:
# Statistiques descriptives:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
# Vérification des valeurs manquantes
print("\nValeurs manquantes par colonne:")
print(df.isnull().sum())
# Out:
# Valeurs manquantes par colonne:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# Heatmap pour vérifier les valeurs nulles/manquantess 
sns.heatmap(df.isnull(),cmap="coolwarm")
plt.title("Carte des valeurs manquantes dans le dataset")
plt.savefig('heatmap.png')
plt.show()

# %%
# Visualisation des corrélations
plt.figure(figsize=(10, 8))

# Sélectionner uniquement les colonnes numériques
df_numeric = df.select_dtypes(include=['float64', 'int64'])

correlation_matrix = df_numeric.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matrice de corrélation des variables')
plt.tight_layout()
plt.savefig('correlation_matrix.png')
plt.show()

# %%
# Visualisation de la distribution des cultures
plt.figure(figsize=(12, 6))
sns.countplot(y='label', data=df)
plt.title('Distribution des cultures')
plt.xlabel('Nombre d\'échantillons')
plt.ylabel('Type de culture')
plt.tight_layout()
plt.savefig('distribution_cultures.png')
plt.show()

# %%
# Préparation des données
X = df.iloc[:, :-1].values  # Toutes les colonnes sauf la dernière (label)
y = df.iloc[:, -1].values   # Dernière colonne (label)

# %%
from sklearn.preprocessing import StandardScaler
# Standardisation des caractéristiques
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
# Séparation en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
print(f"Forme de X_train: {X_train.shape}")
print(f"Forme de X_test: {X_test.shape}")
# Out:
# Forme de X_train: (1760, 7)
# Forme de X_test: (440, 7)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pickle
# Entraînement du modèle Gradient Boosting
gb_classifier = GradientBoostingClassifier(
    n_estimators=100,     # Nombre d'arbres
    learning_rate=0.1,    # Taux d'apprentissage
    max_depth=5,          # Profondeur maximale des arbres
    random_state=42
)
# Entraîner le modèle
gb_classifier.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=5, random_state=42)

# %%
# Prédictions sur l'ensemble de test
y_pred = gb_classifier.predict(X_test)

# Évaluation du modèle
accuracy = accuracy_score(y_test, y_pred)
print(f"\nPrécision du modèle: {accuracy:.4f}")
# Out:
# Précision du modèle: 0.9795

# %%
# Rapport de classification détaillé
print("\nRapport de classification:")
print(classification_report(y_test, y_pred))
# Out:
# Rapport de classification:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       0.91      1.00      0.95        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       0.96      0.96      0.96        27
#       coffee       1.00      1.00      1.00        17
#       cotton       0.94      1.00      0.97        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.88      1.00      0.94        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.92      1.00      0.96        11
#        maize       1.00      0.95      0.98        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      0.96      0.98        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
# ...

# %%
# Matrice de confusion
plt.figure(figsize=(14, 12))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y), yticklabels=np.unique(y))
plt.title('Matrice de confusion')
plt.xlabel('Prédictions')
plt.ylabel('Valeurs réelles')
plt.tight_layout()
plt.savefig('confusion_matrix.png')
plt.show()

# %%
# Importance des caractéristiques
feature_names = df.columns[:-1]
importances = gb_classifier.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10, 6))
plt.title('Importance des caractéristiques')
plt.bar(range(X.shape[1]), importances[indices], align='center')
plt.xticks(range(X.shape[1]), [feature_names[i] for i in indices], rotation=90)
plt.tight_layout()
plt.savefig('feature_importance.png')
plt.show()

# %%
# Visualisation des performances du modèle
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

# %%
# Convertir les labels en format binaire (one-vs-rest)
y_test_bin = label_binarize(y_test, classes=np.unique(y))
n_classes = y_test_bin.shape[1]

# Calculer les probabilités pour chaque classe
y_score = gb_classifier.predict_proba(X_test)

# Calculer la courbe ROC et l'AUC pour chaque classe
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Afficher les courbes ROC pour les 5 premières classes (pour la lisibilité)
plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'orange', 'purple'])
for i, color in zip(range(5), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve de {np.unique(y)[i]} (area = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de faux positifs')
plt.ylabel('Taux de vrais positifs')
plt.title('Courbes ROC pour différentes cultures (5 premières)')
plt.legend(loc="lower right")
plt.savefig('roc_curves.png')
plt.show()

# %%
# Fonction de prédiction pour de nouvelles données
def predict_crop(N, P, K, temperature, humidity, ph, rainfall):
    # Créer un tableau avec les valeurs d'entrée
    input_data = np.array([[N, P, K, temperature, humidity, ph, rainfall]])
    
    # Standardiser les données d'entrée
    input_data_scaled = scaler.transform(input_data)
    
    # Faire la prédiction
    prediction = gb_classifier.predict(input_data_scaled)
    
    # Obtenir les probabilités pour chaque classe
    probabilities = gb_classifier.predict_proba(input_data_scaled)
    
    # Trouver l'indice de la classe prédite
    predicted_idx = np.argmax(probabilities)
    
    return prediction[0], probabilities[0][predicted_idx]

# Exemple de prédiction
N = 90
P = 42
K = 43
temperature = 21
humidity = 82
ph = 6.5
rainfall = 200

predicted_crop, confidence = predict_crop(N, P, K, temperature, humidity, ph, rainfall)
print(f"\nPour les valeurs d'entrée N={N}, P={P}, K={K}, température={temperature}, humidité={humidity}, pH={ph}, précipitations={rainfall}")
print(f"La culture prédite est: {predicted_crop} avec une confiance de {confidence:.4f}")
# Out:
# Pour les valeurs d'entrée N=90, P=42, K=43, température=21, humidité=82, pH=6.5, précipitations=200
# La culture prédite est: rice avec une confiance de 1.0000

# %%
import os
# Sérialisation du modèle et du scaler
model_dir = 'model'
os.makedirs(model_dir, exist_ok=True)

# Enregistrer le modèle
with open(os.path.join(model_dir, 'gradient_boosting_model.pkl'), 'wb') as f:
    pickle.dump(gb_classifier, f)

# Enregistrer le scaler
with open(os.path.join(model_dir, 'scaler.pkl'), 'wb') as f:
    pickle.dump(scaler, f)

# Enregistrer les noms de colonnes et autres métadonnées
metadata = {
    'feature_names': list(feature_names),
    'target_name': 'label',
    'classes': list(np.unique(y))
}

with open(os.path.join(model_dir, 'metadata.pkl'), 'wb') as f:
    pickle.dump(metadata, f)

print(f"\nModèle, scaler et métadonnées sauvegardés dans le dossier '{model_dir}'")
# Out:
# Modèle, scaler et métadonnées sauvegardés dans le dossier 'model'
